# %%
# %matplotlib inline

# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
  global data_index
  batch = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    batch[i] = [k for j, k in enumerate(buffer) if j != skip_window]
    labels[i, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])
for skip_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
  print('\nwith skip_window = %d:' % skip_window)
  print('    batch:', [[reverse_dictionary[bi] for bi in row] for row in batch])
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size)) # brb
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal(
      [vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print(embed)
  embed = tf.reduce_sum(embed, reduction_indices=1)
  print(embed)
  # Compute the softmax loss, using a sample of the negative labels each time.
  # sampled_softmax_loss(weights, biases, inputs, labels, num_sampled, num_classes)
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(
      softmax_weights, softmax_biases, embed, train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("embedding_lookup:0", shape=(128, 2, 128), dtype=float32, device=/device:CPU:0)
# Tensor("Sum:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.104119
# Nearest to he: rna, shark, seduce, caver, nhadau, struma, trilobite, lipschitz,
# Nearest to be: butte, ventspils, kbe, norse, sorrow, ahl, ecclesiology, dominates,
# Nearest to for: emigrate, repaired, religiously, robotics, middlesex, button, communal, boycotted,
# Nearest to more: bitstream, recommending, cake, romanus, toleration, crowding, lasker, csa,
# Nearest to but: hahnemann, provable, vitality, cleared, cooper, references, railways, sparks,
# Nearest to over: aloes, dime, likelihood, earlier, palatalized, tosefta, chemicals, analogs,
# Nearest to d: munch, grattan, detainees, influential, facilitates, sauerkraut, angel, permutations,
# Nearest to that: pigweed, spiny, inadequacy, eisner, maturation, ncp, mints, ces,
# Nearest to three: pavilion, aorist, gras, architecturally, ape, benchers, tor, deepen,
# Nearest to nine: mammary, esc, foreman, makkah, mitosis, syd, refounded, regarded,
# Nearest to a: expel, loy, municipality, disjointed, domes, livestock, megafauna, metaphysics,
# Nearest to there: fortunate, await, wto, transmit, weaning, mori, serbs, pronouns,
# Nearest to on: recessions, komm, idolatry, eml, tramway, quarto, overdosing, moabites,
# Nearest to most: rsdlp, tertullian, networks, einen, self, philistine, nikaya, minotaurs,
# Nearest to these: stewardship, marlin, protested, dimers, accomplice, monthly, bogside, frightening,
# Nearest to two: carrera, simulating, equivalency, furthermore, learning, segment, fermions, monadic,
# Average loss at step 2000: 4.088596
# Average loss at step 4000: 3.561286
# Average loss at step 6000: 3.381097
# Average loss at step 8000: 3.240710
# Average loss at step 10000: 3.175615
# Nearest to he: it, they, who, she, there, carnot, tavola, improvisational,
# Nearest to be: have, been, become, tupac, was, fahrenheit, reticent, were,
# Nearest to for: liga, utilising, jutta, during, of, as, lehrer, under,
# Nearest to more: less, most, recommending, romanus, chinaman, crowding, very, cake,
# Nearest to but: although, outfielder, however, while, nicopolis, akad, print, disgraced,
# Nearest to over: outside, likelihood, earlier, revolted, palatalized, cordite, when, experiential,
# Nearest to d: b, sauerkraut, ascetical, munch, influential, buccaneer, judgments, homologous,
# Nearest to that: which, sets, lawlessness, gassing, this, eisner, lately, benefitted,
# Nearest to three: four, two, eight, five, six, seven, nine, zero,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to a: expel, darts, maribor, another, no, livestock, legislators, any,
# Nearest to there: it, they, he, mash, rmi, highlights, await, which,
# Nearest to on: in, at, enslaved, during, upon, opportunistic, tramway, boltzmann,
# Nearest to most: more, petroleum, shermer, voyager, salk, dedekind, colon, some,
# Nearest to these: claremont, manuel, duluth, all, marlin, plural, buyers, many,
# Nearest to two: three, six, four, five, eight, nine, seven, one,
# Average loss at step 12000: 3.203954
# Average loss at step 14000: 3.153522
# Average loss at step 16000: 3.173814
# Average loss at step 18000: 3.128419
# Average loss at step 20000: 2.990776
# Nearest to he: she, it, they, who, there, mockingbird, then, tavola,
# Nearest to be: have, been, being, is, were, was, reticent, refer,
# Nearest to for: when, after, utilising, of, in, jutta, without, insulate,
# Nearest to more: less, most, very, romanus, subdominant, suspect, better, chinaman,
# Nearest to but: however, and, although, while, hypertext, which, see, andre,
# Nearest to over: outside, cordite, likelihood, vyacheslav, welwyn, revolted, transfers, mechanized,
# Nearest to d: b, influential, ascetical, nepal, sauerkraut, v, buccaneer, pharmacologic,
# Nearest to that: which, what, this, however, rejoiced, benefitted, when, marija,
# Nearest to three: six, eight, four, five, seven, two, nine, zero,
# Nearest to nine: eight, six, seven, five, zero, four, three, one,
# Nearest to a: the, another, any, relatively, no, every, megafauna, grown,
# Nearest to there: they, it, he, mash, these, sometimes, often, latvijas,
# Nearest to on: upon, in, during, against, about, despite, cutler, xxxiii,
# Nearest to most: more, petroleum, many, shermer, nucleosome, some, myspace, dedekind,
# Nearest to these: many, some, such, they, all, several, there, which,
# Nearest to two: three, six, five, seven, four, one, eight, zero,
# Average loss at step 22000: 3.075678
# Average loss at step 24000: 3.032766
# Average loss at step 26000: 2.999161
# Average loss at step 28000: 3.032742
# Average loss at step 30000: 3.002496
# Nearest to he: she, it, they, who, there, mockingbird, lagrangian, microfilm,
# Nearest to be: been, being, have, reticent, is, nervousness, fahrenheit, become,
# Nearest to for: offside, landmine, after, honorifics, jutta, whitman, postwar, against,
# Nearest to more: less, most, very, highly, greater, quite, rather, longer,
# Nearest to but: however, and, see, which, although, though, while, hypertext,
# Nearest to over: outside, cordite, through, cleaners, around, embarrassed, vyacheslav, out,
# Nearest to d: b, ascetical, sauerkraut, buccaneer, v, anticonvulsant, kidney, nepal,
# Nearest to that: which, what, however, this, about, eileen, where, when,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to a: the, another, any, tombalbaye, greve, motorcycle, resettled, maribor,
# Nearest to there: they, it, sometimes, he, now, often, these, still,
# Nearest to on: upon, in, about, privacy, through, graceful, against, novella,
# Nearest to most: more, some, many, shermer, less, dedekind, petroleum, nucleosome,
# Nearest to these: some, many, such, several, all, various, those, both,
# Nearest to two: three, four, six, five, seven, nine, eight, one,
# Average loss at step 32000: 2.824305
# Average loss at step 34000: 2.955295
# Average loss at step 36000: 2.943484
# Average loss at step 38000: 2.942764
# Average loss at step 40000: 2.926154
# Nearest to he: she, it, they, there, who, microfilm, we, tavola,
# Nearest to be: been, being, is, was, have, become, karachi, reticent,
# Nearest to for: landmine, utilising, when, against, larwood, asymmetric, offside, after,
# Nearest to more: less, very, most, quite, netbios, highly, rather, patches,
# Nearest to but: however, although, and, while, hypertext, see, than, nicopolis,
# Nearest to over: off, around, outside, through, anticipating, adaption, out, cordite,
# Nearest to d: b, nepal, sauerkraut, ascetical, monsoon, clearances, lefty, influential,
# Nearest to that: which, however, what, about, uncles, penicillin, alegre, peggy,
# Nearest to three: five, six, two, seven, four, eight, nine, zero,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to a: another, the, graze, expel, netherland, any, percentile, touchstone,
# Nearest to there: they, it, he, sometimes, now, she, still, often,
# Nearest to on: upon, through, amplification, xbox, during, firenze, about, automated,
# Nearest to most: more, many, less, some, nucleosome, sapkowski, because, unpaid,
# Nearest to these: those, such, some, several, many, various, which, both,
# Nearest to two: three, five, six, four, seven, eight, nine, one,
# Average loss at step 42000: 2.951299
# Average loss at step 44000: 2.957269
# Average loss at step 46000: 2.907478
# Average loss at step 48000: 2.872272
# Average loss at step 50000: 2.848446
# Nearest to he: she, it, they, there, we, who, eventually, subsequently,
# Nearest to be: been, being, have, become, are, is, explore, moynihan,
# Nearest to for: including, melanogaster, when, utilising, although, honorifics, liga, offside,
# Nearest to more: less, most, very, quite, larger, longer, stronger, rather,
# Nearest to but: however, although, hypertext, though, while, and, which, see,
# Nearest to over: around, off, anticipating, outside, out, stm, adaption, cordite,
# Nearest to d: b, nepal, ebook, sauerkraut, ascetical, caucus, compressed, anticonvulsant,
# Nearest to that: which, what, however, why, tagging, meriwether, alegre, how,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to a: any, the, expel, resettled, graze, greve, another, conducting,
# Nearest to there: they, it, he, we, often, usually, sometimes, now,
# Nearest to on: upon, at, against, during, about, in, under, opportunistic,
# Nearest to most: more, many, some, less, several, especially, shermer, all,
# Nearest to these: many, several, some, various, such, those, certain, examples,
# Nearest to two: three, four, six, seven, eight, five, one, nine,
# Average loss at step 52000: 2.892122
# Average loss at step 54000: 2.862046
# Average loss at step 56000: 2.861628
# Average loss at step 58000: 2.754514
# Average loss at step 60000: 2.832178
# Nearest to he: she, it, they, who, there, eventually, mockingbird, finally,
# Nearest to be: been, become, being, have, were, was, explore, is,
# Nearest to for: against, without, landmine, yazoo, tilde, utilising, jutta, postwar,
# Nearest to more: less, most, very, quite, stronger, larger, highly, rather,
# Nearest to but: however, although, and, though, see, hypertext, beecher, which,
# Nearest to over: around, outside, anticipating, across, through, cordite, adaption, icj,
# Nearest to d: b, nepal, dimensional, ascetical, lefty, michelle, supervised, plasmodium,
# Nearest to that: which, what, however, about, fourteenth, how, follies, infallibility,
# Nearest to three: four, two, six, seven, five, eight, nine, zero,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to a: another, graze, expel, the, postmillennialism, companionship, maribor, motorcycle,
# Nearest to there: they, it, he, she, often, located, sometimes, gloves,
# Nearest to on: upon, within, in, through, at, during, under, firenze,
# Nearest to most: more, many, some, less, especially, bella, use, several,
# Nearest to these: several, those, many, such, various, some, they, list,
# Nearest to two: three, four, six, eight, seven, one, five, nine,
# Average loss at step 62000: 2.835355
# Average loss at step 64000: 2.775764
# Average loss at step 66000: 2.765513
# Average loss at step 68000: 2.721383
# Average loss at step 70000: 2.782011
# Nearest to he: she, it, they, who, there, we, eventually, quickly,
# Nearest to be: been, become, have, being, is, seem, remain, fully,
# Nearest to for: against, landmine, armando, clearwater, utilising, enhancements, magee, knicks,
# Nearest to more: less, most, very, stronger, highly, larger, quite, rather,
# Nearest to but: however, although, though, and, which, that, while, hypertext,
# Nearest to over: around, off, outside, across, embarrassed, cordite, away, eikon,
# Nearest to d: b, nepal, lefty, traversed, oakenfold, sauerkraut, sein, seals,
# Nearest to that: which, what, however, but, fourteenth, heathen, alegre, uncles,
# Nearest to three: five, four, two, seven, six, eight, nine, zero,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to a: another, the, graze, any, expel, companionship, enough, resettled,
# Nearest to there: they, it, she, he, we, sometimes, often, augmentation,
# Nearest to on: upon, within, through, at, in, under, during, around,
# Nearest to most: more, many, less, some, especially, shermer, scuola, hordes,
# Nearest to these: those, several, some, various, many, they, such, list,
# Nearest to two: three, four, six, seven, five, one, eight, nine,
# Average loss at step 72000: 2.798801
# Average loss at step 74000: 2.641283
# Average loss at step 76000: 2.801800
# Average loss at step 78000: 2.825992
# Average loss at step 80000: 2.778131
# Nearest to he: she, it, they, who, there, we, i, sulphur,
# Nearest to be: been, become, explore, have, remain, seem, was, get,
# Nearest to for: without, when, after, while, offside, utilising, postwar, ach,
# Nearest to more: less, very, most, quite, highly, increasingly, rather, better,
# Nearest to but: however, although, though, which, and, frosts, while, too,
# Nearest to over: around, off, through, cordite, across, away, outside, almost,
# Nearest to d: b, dimensional, nepal, kosar, sauerkraut, lefty, ebook, ascetical,
# Nearest to that: which, what, however, this, uncles, alegre, eo, but,
# Nearest to three: five, four, six, seven, two, eight, nine, one,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to a: another, any, graze, the, hyundai, provoking, maribor, enough,
# Nearest to there: they, it, she, we, he, sometimes, usually, still,
# Nearest to on: upon, in, through, within, during, around, under, against,
# Nearest to most: more, many, less, some, several, greatest, especially, all,
# Nearest to these: many, several, those, some, they, such, both, list,
# Nearest to two: three, four, eight, six, five, seven, one, nine,
# Average loss at step 82000: 2.662020
# Average loss at step 84000: 2.767964
# Average loss at step 86000: 2.737695
# Average loss at step 88000: 2.752878
# Average loss at step 90000: 2.736931
# Nearest to he: she, it, they, there, who, tavola, we, formally,
# Nearest to be: become, been, have, being, remain, refer, get, seem,
# Nearest to for: landmine, when, while, armando, utilising, without, yazoo, enclose,
# Nearest to more: less, most, quite, very, highly, increasingly, stronger, smaller,
# Nearest to but: however, although, though, and, see, disjunctive, beecher, banting,
# Nearest to over: around, off, across, through, about, away, cordite, out,
# Nearest to d: b, dimensional, nepal, sauerkraut, sein, n, traversed, g,
# Nearest to that: which, what, however, how, why, heathen, alegre, instead,
# Nearest to three: four, six, five, two, eight, seven, nine, zero,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to a: another, the, graze, any, greve, expel, postmillennialism, every,
# Nearest to there: they, it, she, he, we, sometimes, usually, still,
# Nearest to on: upon, in, through, within, autobiographical, regarding, at, privacy,
# Nearest to most: more, many, some, less, especially, nucleosome, all, largest,
# Nearest to these: those, several, such, many, various, some, multiple, both,
# Nearest to two: three, four, six, eight, seven, five, one, nine,
# Average loss at step 92000: 2.676032
# Average loss at step 94000: 2.725547
# Average loss at step 96000: 2.700600
# Average loss at step 98000: 2.364950
# Average loss at step 100000: 2.394747
# Nearest to he: she, it, they, there, we, who, tavola, quickly,
# Nearest to be: become, been, being, have, remain, seem, were, is,
# Nearest to for: utilising, after, without, against, when, tilde, thoroughbred, despite,
# Nearest to more: less, most, quite, stronger, very, greater, highly, better,
# Nearest to but: however, though, although, and, while, did, sculpted, saw,
# Nearest to over: off, away, around, across, through, cordite, within, icj,
# Nearest to d: b, nepal, traversed, lefty, oakenfold, paris, register, ascetical,
# Nearest to that: which, however, what, why, how, whom, heathen, eileen,
# Nearest to three: four, five, six, seven, eight, nine, two, zero,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to a: another, postmillennialism, graze, hyundai, floss, expel, companionship, the,
# Nearest to there: they, he, it, she, we, sometimes, still, usually,
# Nearest to on: upon, falcons, at, through, privacy, oscilloscope, firenze, in,
# Nearest to most: more, less, some, many, especially, highly, particularly, greatest,
# Nearest to these: several, such, those, certain, some, many, examples, both,
# Nearest to two: three, four, five, six, eight, seven, nine, one,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(16,16))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
